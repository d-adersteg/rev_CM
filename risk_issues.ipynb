# %%
# %%zeus_sql
#
# SELECT
# *
# FROM risk.risk_issues
# WHERE (risk_type_id = 186 OR additional_risk_type_ids LIKE '%186%')
# AND issue_state NOT IN ('invalid', 'deleted')
# AND reporting_date >= TIMESTAMP '2024-01-01 00:00:00 UTC'
# ORDER BY responsible_department, cause_category_l1
# Out:
# [2026-01-26 17:51:40.828730] Connected successfully.
# Query <a href='https://eu-zeus-ui.revolut.com/ui/query.html?20260126_175140_20520_pcjsw'>20260126_175140_20520_pcjsw</a> <b>finished</b>
#                                        id              issue_state  report_id  \
# 0    d734b3d9-4b8b-4d32-92b3-cb7f9496787a                 resolved      30177
# 1    1464e95f-a755-42bd-8f40-75a7c1fd238b  remediation_in_progress      30971
# 2    734f1a6e-6a27-43d0-b69b-8fe7c3f795d0           scoping_review      33815
# 3    947c5414-2187-4710-babb-d2537c322527                 resolved      30176
# 4    4433ec43-8025-4ff8-aaae-8ac18ed4fd28  remediation_in_progress      30974
# ..                                    ...                      ...        ...
# 215  3a1666fe-ec1a-4fe3-89e2-7f92f2d64365                 resolved      27472
# 216  2ec36795-c480-4228-bfa3-5d03fd924d78                 resolved      15897
# 217  75c007bf-41a3-4a36-b6f2-f588135b4ccb                 resolved      28428
# 218  c2a2f6e4-7215-4f29-908c-d61ef4cd6c2d                 resolved      18057
# 219  840a05c0-cae9-4d50-a939-3da88e429021                 resolved      18058
#
#                         created_date                     updated_date  \
# 0   2025-09-01 17:40:53.576631+00:00 2025-09-23 15:13:23.712267+00:00
# 1   2025-09-29 11:24:37.632844+00:00 2025-12-04 09:25:46.129635+00:00
# 2   2025-12-31 12:35:32.324715+00:00 2026-01-22 17:11:50.232911+00:00
# 3   2025-09-01 17:38:36.263690+00:00 2025-10-02 11:49:32.239789+00:00
# 4   2025-09-29 11:42:51.902284+00:00 2025-12-04 09:25:45.994911+00:00
# ..                               ...                              ...
# 215 2025-04-25 09:26:41.799806+00:00 2026-01-19 13:36:06.991786+00:00
# 216 2024-01-22 21:55:47.417886+00:00 2025-07-22 15:27:40.134268+00:00
# 217 2025-06-16 19:58:59.446763+00:00 2025-10-30 13:38:29.219899+00:00
# 218 2024-08-02 15:16:52.087502+00:00 2025-12-04 16:08:13.369354+00:00
# 219 2024-08-02 15:20:10.305722+00:00 2025-12-04 16:07:55.517633+00:00
#
#                    assignee_email      remediation_due_date  \
# 0       atirek.rajpal@revolut.com 2025-09-30 20:00:00+00:00
# 1    penelope.schuwer@revolut.com 2026-01-16 20:00:00+00:00
# 2             j.huang@revolut.com 2026-04-30 20:00:00+00:00
# 3     vincent.marotte@revolut.com 2025-10-31 20:00:00+00:00
# 4    penelope.schuwer@revolut.com 2026-01-16 20:00:00+00:00
# ..                            ...                       ...
# 215   yeray.fernandez@revolut.com 2026-03-13 20:00:00+00:00
# 216   sofia.abrunhosa@revolut.com 2024-02-15 00:00:00+00:00
# 217      laura.setien@revolut.com 2025-08-01 22:59:59+00:00
# 218       lisa.curtin@revolut.com 2024-11-19 00:00:00+00:00
# 219       lisa.curtin@revolut.com 2024-12-31 00:00:00+00:00
#
#     additional_risk_ids additional_risk_type_ids  \
# 0                    []                     None
# 1                    []                     None
# 2                    []                     None
# 3                    []                     None
# 4                    []                     None
# ..                  ...                      ...
# 215                  []                     None
# 216                  []                     None
# 217             [11416]                     None
# 218                  []                     None
# 219                  []                     None
#
#                          cause_categories  ... brm_status brm_team_id  \
# 0                                    [60]  ...     active      1919.0
# 1                                    [66]  ...     active      1919.0
# 2                                    [66]  ...     active      1919.0
# 3                                    [60]  ...     active      1919.0
# 4                                    [70]  ...     active      1919.0
# ..                                    ...  ...        ...         ...
# 215                          [88, 89, 90]  ...       None         NaN
# 216  [31, 32, 33, 34, 35, 36, 37, 38, 39]  ...       None         NaN
# 217                  [66, 67, 68, 69, 70]  ...       None         NaN
# 218                                  None  ...       None         NaN
# 219                                  None  ...       None         NaN
#
#                                             brm_team brm_department_id  \
# 0    Services · Acquiring · Risk & Compliance · Core               9.0
# 1    Services · Acquiring · Risk & Compliance · Core               9.0
# 2    Services · Acquiring · Risk & Compliance · Core               9.0
# 3    Services · Acquiring · Risk & Compliance · Core               9.0
# 4    Services · Acquiring · Risk & Compliance · Core               9.0
# ..                                               ...               ...
# 215                                             None               NaN
# 216                                             None               NaN
# 217                                             None               NaN
# 218                                             None               NaN
# 219                                             None               NaN
#
#     brm_department brm_department_type related_exam_subjects  \
# 0        Acquiring             TECH_CO
# 1        Acquiring             TECH_CO
# 2        Acquiring             TECH_CO
# 3        Acquiring             TECH_CO
# 4        Acquiring             TECH_CO
# ..             ...                 ...                   ...
# 215           None                None
# 216           None                None
# 217           None                None
# 218           None                None
# 219           None                None
#
#     related_exam_regions related_exam_name related_exam_examiner
# 0
# 1
# 2
# 3
# 4
# ..                   ...               ...                   ...
# 215
# 216
# 217
# 218
# 219
#
# [220 rows x 154 columns]
